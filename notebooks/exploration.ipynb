# %% [markdown]
# # Data exploration
#
# A starter notebook for the datasets in `../data`.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_theme()
data_dir = Path.cwd().parent / 'data'
sorted(data_dir.glob('*.parquet'))
